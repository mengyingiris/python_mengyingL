# %%
# 1) What is the output of the following code and why?  D

# var1 = 1
# var2 = 2
# var3 = "3"

# print(var1 + var2 + var3)

# a) 6 
# b) 33 
# c) 3 + 3 
# d) Error 

# 2) What is the output of the following code?  B

# str = "pynative"

# print (str[1:3])

# a) py
# b) yn
# c) pyn
# d) yna

# 3) What is the output of the following code?  C 

# var= "James Bond"
# print(var[2::-1])

# a) Jam
# b) dno
# c) maJ
# d) dnoB semaJ

# 4) What is the output of the following code?  A

# var = "James" * 2  * 3
# print(var)

# a) JamesJamesJamesJamesJamesJames
# b) JamesJamesJamesJamesJames
# c) Error: invalid syntax

# 5) Get rid of the non fruit item:  print(sweets.pop())

# sweets = ['apple', 'bananas', 'cantelopes', 'donut']

# 6) Find "santa" in the variable "house"   print(house[0][1])


# room1=['gabe', 'greg']
# room2=['michelle','santa','stacey']
# room3=['adam','sam', 'melissa']
# house= [room2, room1, room3] 

# 7) A dictionary is the best way to store a sequence of events like a recipe. T 

# True or false? 
 

# 8) Remove all dupes                print(set(names))
# names = ['mary', 'bob', 'jessica', 'pierre', 'bob', 'jennifer', 'chris', 
#          'christina', 'tina', 'mary', 'tina', 'bob', 'michelle','jennifer']

# 9) What's the difference between = and == ? 
# = assigns values from right side operands to the left side operand. 
# == checks if the values of two operands are equal or not.

# %%
poemP1 = {'location': ['In the Olympic Peninsular', 'At the Pier 57', 'By the Lake Union','In the uw Quad'], 'title' : ['last spring','mid march in seattle']}
print(poemP1['title'][0].rjust(153).upper()+poemP1['title'][1].rjust(28).upper())
print('\n')
print(poemP1['location'][0].upper())
string1 = "Wandering at the\t Getting lost in the\t Lingering around the"
string2 = "Ruby Beach\tHoh Rainforest\t  Lake Crescent"
print(string1.expandtabs(40))
print(string2.expandtabs(30).upper().rjust(100))
print('\n')
print(poemP1['location'][1].upper())
string3 = "During the golden hour"
string4 = "City skyline shone"
print(string3.rjust(60))
print(string4.rjust(100))
print('\n')
print(poemP1['location'][2].upper())
string5 = "picnic blanket\t dots of wildflowers\t  yacht club\t floating paraglider"
print(string5.expandtabs(40))
print('\n')
print(poemP1['location'][3].upper())
string6 = "sakura fell, 5 centimeters per second"
print(string6.rjust(70).upper())
print('\n')
string7 = "spring came and come"
print(string7.upper())
# Out:
#                                                                                                                                               LAST SPRING        MID MARCH IN SEATTLE
#
#
# IN THE OLYMPIC PENINSULAR
# Wandering at the                         Getting lost in the                     Lingering around the
#                          RUBY BEACH                    HOH RAINFOREST                  LAKE CRESCENT
#
#
# AT THE PIER 57
#                                       During the golden hour
#                                                                                   City skyline shone
#
#
# BY THE LAKE UNION
# picnic blanket                           dots of wildflowers                      yacht club                             floating paraglider
#
#
# IN THE UW QUAD
#                                  SAKURA FELL, 5 CENTIMETERS PER SECOND
#
#
# SPRING CAME AND COME
